# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('wydarzenia_karnet_krakow_z_obrazkami_20250530-062133.csv')

# %%
df.head()
# Out:
#    id_strony                                          tytul  \
# 0      57404                            Salon Sztuki Polart
# 1      56184                  Jarmark Bożonarodzeniowy 2024
# 2      57435  Żywa szopka i koncerty kolęd przy ul. Bociana
# 3      57550                Jedno Muzeum, dwa skarby UNESCO
# 4      47877                            Mistrz i Małgorzata
#
#    typ_wydarzenia_lista               data_lista  \
# 0  W gminach Metropolii  18.10.2024 - 12.01.2025
# 1     Targi i kiermasze  29.11.2024 - 01.01.2025
# 2    Dziecięce różności  15.12.2024 - 06.01.2025
# 3  W gminach Metropolii  30.12.2024 - 28.02.2025
# 4   Spektakle teatralne        19.12.2024, 11:30
#
#                                    lokalizacja_lista  \
# 0  Muzeum Żup Krakowskich Wieliczka, ul. Zamkowa ...
# 1                                       Rynek Główny
# 2                                                NaN
# 3  Muzeum Żup Krakowskich w Wieliczce – Ekspozycj...
# 4                     Teatr Groteska, ul. Skarbowa 2
#
#                            link_do_obrazka_lista  \
# 0  http://media.krakow.travel/photos/70846/m.jpg
# 1  http://media.krakow.travel/photos/63994/m.jpg
# 2  http://media.krakow.travel/photos/70864/m.jpg
# 3  http://media.krakow.travel/photos/70978/m.jpg
# 4  http://media.krakow.travel/photos/60246/m.jpg
#
#        sciezka_do_pobranego_obrazka
# 0  obrazy_wydarzen_karnet/57404.jpg
# 1  obrazy_wydarzen_karnet/56184.jpg
# 2  obrazy_wydarzen_karnet/57435.jpg
# 3  obrazy_wydarzen_karnet/57550.jpg
# 4  obrazy_wydarzen_karnet/47877.jpg

# %% [markdown]
# data rozpoczecia, zakonczenia, lokalizacja -> obiekt, ulica, miasto;

# %% [markdown]
# unikalne wydarznia,

# %% [markdown]
# ## rozdzielenie lokalizacji

# %%
lok = pd.DataFrame()

# %%
lok['obiekty'] = df["lokalizacja_lista"].str.split(",").str[0].str.strip()
lok['ulice'] = df["lokalizacja_lista"].str.split(",").str[1].str.strip()
lok['miasta'] = df["lokalizacja_lista"].str.split(",").str[2].str.strip()

# %%
lok['miasta'] = lok['miasta'].fillna('Kraków')

# %%
lok
# Out:
#                                                 obiekty               ulice  \
# 0                      Muzeum Żup Krakowskich Wieliczka       ul. Zamkowa 8
# 1                                          Rynek Główny                 NaN
# 2                                                   NaN                 NaN
# 3     Muzeum Żup Krakowskich w Wieliczce – Ekspozycj...  ul. Daniłowicza 10
# 4                                        Teatr Groteska      ul. Skarbowa 2
# ...                                                 ...                 ...
# 5798                  Muzeum Fonografii w Niepołomicach       ul. Zamkowa 4
# 5799                                             Planty                 NaN
# 5800                    Stacja Muzeum Czernichów Główny       ul. Wiślana 3
# 5801                  Muzeum Fonografii w Niepołomicach       ul. Zamkowa 4
# 5802                                             Planty                 NaN
#
#            miasta
# 0       Wieliczka
# 1          Kraków
# 2          Kraków
# 3       Wieliczka
# 4          Kraków
# ...           ...
# 5798  Niepołomice
# 5799       Kraków
# 5800   Czernichów
# 5801  Niepołomice
# 5802       Kraków
#
# [5803 rows x 3 columns]

# %%
df[['obiekty', 'ulice', 'miasta']] = lok[['obiekty', 'ulice', 'miasta']]
df = df.drop('lokalizacja_lista', axis=1)

# %%
df.head()
# Out:
#    id_strony                                          tytul  \
# 0      57404                            Salon Sztuki Polart
# 1      56184                  Jarmark Bożonarodzeniowy 2024
# 2      57435  Żywa szopka i koncerty kolęd przy ul. Bociana
# 3      57550                Jedno Muzeum, dwa skarby UNESCO
# 4      47877                            Mistrz i Małgorzata
#
#    typ_wydarzenia_lista               data_lista  \
# 0  W gminach Metropolii  18.10.2024 - 12.01.2025
# 1     Targi i kiermasze  29.11.2024 - 01.01.2025
# 2    Dziecięce różności  15.12.2024 - 06.01.2025
# 3  W gminach Metropolii  30.12.2024 - 28.02.2025
# 4   Spektakle teatralne        19.12.2024, 11:30
#
#                            link_do_obrazka_lista  \
# 0  http://media.krakow.travel/photos/70846/m.jpg
# 1  http://media.krakow.travel/photos/63994/m.jpg
# 2  http://media.krakow.travel/photos/70864/m.jpg
# 3  http://media.krakow.travel/photos/70978/m.jpg
# 4  http://media.krakow.travel/photos/60246/m.jpg
#
#        sciezka_do_pobranego_obrazka  \
# 0  obrazy_wydarzen_karnet/57404.jpg
# 1  obrazy_wydarzen_karnet/56184.jpg
# 2  obrazy_wydarzen_karnet/57435.jpg
# 3  obrazy_wydarzen_karnet/57550.jpg
# 4  obrazy_wydarzen_karnet/47877.jpg
#
#                                              obiekty               ulice  \
# 0                   Muzeum Żup Krakowskich Wieliczka       ul. Zamkowa 8
# 1                                       Rynek Główny                 NaN
# 2                                                NaN                 NaN
# 3  Muzeum Żup Krakowskich w Wieliczce – Ekspozycj...  ul. Daniłowicza 10
# 4                                     Teatr Groteska      ul. Skarbowa 2
#
#       miasta
# 0  Wieliczka
# 1     Kraków
# 2     Kraków
# 3  Wieliczka
# 4     Kraków

# %% [markdown]
# ## Rozdzielenie daty

# %%
daty = pd.DataFrame()

# %%
daty['data_rozpoczecia'] = df['data_lista'].str.split("-").str[0].str.strip()
daty['data_zakonczenia'] = df['data_lista'].str.split("-").str[1].str.strip()

# %%
daty['godzina_rozpoczecia'] = daty['data_rozpoczecia'].str.split(",").str[1].str.strip()
daty['data_rozpoczecia'] = daty['data_rozpoczecia'].str.split(",").str[0].str.strip()

# %%
daty['czy_stale'] = np.nan

# %%
wanted_str = 'Wydarzenie stałe'
# Znajdź wiersze zawierające szukany string
mask = daty['data_rozpoczecia'].str.contains(wanted_str, na=False)

# Przenieś do kolumny docelowej i zastąp NULL
daty.loc[mask, 'czy_stale'] = daty.loc[mask, 'data_rozpoczecia']
daty.loc[mask, 'data_rozpoczecia'] = np.nan
# Out:
# C:\Users\lolma\AppData\Local\Temp\ipykernel_7268\2197793019.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['Wydarzenie stałe' 'Wydarzenie stałe' 'Wydarzenie stałe' ...
#  'Wydarzenie stałe' 'Wydarzenie stałe' 'Wydarzenie stałe']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   daty.loc[mask, 'czy_stale'] = daty.loc[mask, 'data_rozpoczecia']

# %%
daty
# Out:
#      data_rozpoczecia data_zakonczenia godzina_rozpoczecia         czy_stale
# 0          18.10.2024       12.01.2025                 NaN               NaN
# 1          29.11.2024       01.01.2025                 NaN               NaN
# 2          15.12.2024       06.01.2025                 NaN               NaN
# 3          30.12.2024       28.02.2025                 NaN               NaN
# 4          19.12.2024              NaN               11:30               NaN
# ...               ...              ...                 ...               ...
# 5798              NaN              NaN                 NaN  Wydarzenie stałe
# 5799              NaN              NaN                 NaN  Wydarzenie stałe
# 5800              NaN              NaN                 NaN  Wydarzenie stałe
# 5801              NaN              NaN                 NaN  Wydarzenie stałe
# 5802              NaN              NaN                 NaN  Wydarzenie stałe
#
# [5803 rows x 4 columns]

# %%
df[['data_rozpoczecia',	'data_zakonczenia',	'godzina_rozpoczecia',	'czy_stale']] = daty[['data_rozpoczecia',	'data_zakonczenia',	'godzina_rozpoczecia',	'czy_stale']]
df = df.drop('data_lista', axis=1)

# %% [markdown]
# sortowanie i filty

# %%
from datetime import datetime
df['data_rozpoczecia'] = pd.to_datetime(df['data_rozpoczecia'], dayfirst=True, errors='coerce')
df['data_zakonczenia'] = pd.to_datetime(df['data_zakonczenia'], dayfirst=True, errors='coerce')

# Pobierz dzisiejszą datę
dzisiaj = datetime.now().date()

# Filtrowanie:
# 1. Wydarzenia, które się jeszcze nie rozpoczęły (data rozpoczęcia > dzisiaj)
# 2. LUB wydarzenia stałe (czy_stale == 'Wydarzenie stałe')
df_filtrowane = df[
    (df['data_rozpoczecia'].dt.date > dzisiaj) |
    (df['czy_stale'] == 'Wydarzenie stałe')
]

# Opcjonalnie: sortowanie po dacie rozpoczęcia
df = df_filtrowane.sort_values(by='data_rozpoczecia', na_position='last')

# %%
df
# Out:
#       id_strony                                              tytul  \
# 2951      53439                             Przygody Tomka Sawyera
# 2041      56500                            MET Opera w Kinie Kijów
# 2694      53439                             Przygody Tomka Sawyera
# 3497      59719  Sto nocnych zjaw. Duchy, demony i upiory w szt...
# 1450      53439                             Przygody Tomka Sawyera
# ...         ...                                                ...
# 5798      53870  Muzeum Fonografii w Niepołomicach – wystawa stała
# 5799      38200                                Projekt Kody Miasta
# 5800      53915                 Ostatnia Kolejka Czernichów Główny
# 5801      53870  Muzeum Fonografii w Niepołomicach – wystawa stała
# 5802      38200                                Projekt Kody Miasta
#
#       typ_wydarzenia_lista                          link_do_obrazka_lista  \
# 2951   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# 2041        Pokazy filmowe  http://media.krakow.travel/photos/69867/m.jpg
# 2694   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# 3497       Wystawy czasowe  http://media.krakow.travel/photos/73205/m.jpg
# 1450   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# ...                    ...                                            ...
# 5798  W gminach Metropolii  http://media.krakow.travel/photos/67020/m.jpg
# 5799     Akcje czytelnicze  http://media.krakow.travel/photos/47814/m.jpg
# 5800  W gminach Metropolii  http://media.krakow.travel/photos/66901/m.jpg
# 5801  W gminach Metropolii  http://media.krakow.travel/photos/67020/m.jpg
# 5802     Akcje czytelnicze  http://media.krakow.travel/photos/47814/m.jpg
#
#           sciezka_do_pobranego_obrazka  \
# 2951  obrazy_wydarzen_karnet/53439.jpg
# 2041  obrazy_wydarzen_karnet/56500.jpg
# 2694  obrazy_wydarzen_karnet/53439.jpg
# 3497  obrazy_wydarzen_karnet/59719.jpg
# 1450  obrazy_wydarzen_karnet/53439.jpg
# ...                                ...
# 5798  obrazy_wydarzen_karnet/53870.jpg
# 5799  obrazy_wydarzen_karnet/38200.jpg
# 5800  obrazy_wydarzen_karnet/53915.jpg
# 5801  obrazy_wydarzen_karnet/53870.jpg
# 5802  obrazy_wydarzen_karnet/38200.jpg
#
#                                            obiekty                ulice  \
# 2951  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# 2041                                    Kino Kijów  al. Krasińskiego 34
# 2694  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# 3497   Muzeum Sztuki i Techniki Japońskiej Manggha  ul. Konopnickiej 26
# 1450  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# ...                                            ...                  ...
# 5798             Muzeum Fonografii w Niepołomicach        ul. Zamkowa 4
# 5799                                        Planty                  NaN
# 5800               Stacja Muzeum Czernichów Główny        ul. Wiślana 3
# 5801             Muzeum Fonografii w Niepołomicach        ul. Zamkowa 4
# 5802                                        Planty                  NaN
#
#            miasta data_rozpoczecia data_zakonczenia godzina_rozpoczecia  \
# 2951       Kraków       2025-06-01              NaT               11:00
# 2041       Kraków       2025-06-01              NaT               18:55
# 2694       Kraków       2025-06-01              NaT               11:00
# 3497       Kraków       2025-06-01       2025-08-31                 NaN
# 1450       Kraków       2025-06-01              NaT               11:00
# ...           ...              ...              ...                 ...
# 5798  Niepołomice              NaT              NaT                 NaN
# 5799       Kraków              NaT              NaT                 NaN
# 5800   Czernichów              NaT              NaT                 NaN
# 5801  Niepołomice              NaT              NaT                 NaN
# 5802       Kraków              NaT              NaT                 NaN
#
#              czy_stale
# 2951               NaN
# 2041               NaN
# 2694               NaN
# 3497               NaN
# 1450               NaN
# ...                ...
# 5798  Wydarzenie stałe
# 5799  Wydarzenie stałe
# 5800  Wydarzenie stałe
# 5801  Wydarzenie stałe
# 5802  Wydarzenie stałe
#
# [3132 rows x 12 columns]

# %% [markdown]
# ## Tworzenie hasztagów

# %%
df['typ_wydarzenia_lista'].unique()
# Out:
# array(['Spektakle teatralne', 'Pokazy filmowe', 'Wystawy czasowe',
#        'Inne przedstawienia', 'Muzyka klasyczna',
#        'Widowiska plenerowe i happeningi', 'W gminach Metropolii',
#        'Spotkania i slajdowiska', 'Spotkania i wykłady literackie',
#        'Kabaret', 'Spektakle taneczne', 'Cykle filmowe',
#        'Muzyka rozrywkowa', 'Wykłady, spacery i warsztaty artystyczne',
#        'Inne wydarzenia literackie', 'Wydarzenia sportowe',
#        'Festiwale i przeglądy filmowe', 'Muzyka klubowa',
#        'Festiwale muzyczne', 'Inne koncerty', 'Festiwale',
#        'Targi i kiermasze', 'Pozostałe', 'Dziecięce różności',
#        'Festiwale teatralne', 'Wystawy stałe', 'Akcje czytelnicze'],
#       dtype=object)

# %%
import re

kategorie = df['typ_wydarzenia_lista']

def generuj_hashtagi(nazwa):
    if nazwa == 'W gminach Metropolii':
        return '#WGminach #Metropolii'

    nazwa = nazwa.replace(',', ' i')

    czesci = [cz.strip() for cz in re.split(r'\bi\b', nazwa, flags=re.IGNORECASE)]

    # generuj hashtagi
    hashtagi = []
    for cz in czesci:
        if cz:
            slowa = cz.lower().split()
            if len(slowa) == 1:
                hashtagi.append(f'#{slowa[0]}')
            else:
                hashtagi.extend([f'#{s}' for s in slowa])
    return ' '.join(hashtagi)

df1 = pd.DataFrame({'kategoria': kategorie})

df['hashtagi'] = df1['kategoria'].apply(generuj_hashtagi)

# %%
import numpy as np
df['czy_na_zewnatrz'] = np.random.randint(0, 2, size=len(df))

# %%
df
# Out:
#       id_strony                                              tytul  \
# 2951      53439                             Przygody Tomka Sawyera
# 2041      56500                            MET Opera w Kinie Kijów
# 2694      53439                             Przygody Tomka Sawyera
# 3497      59719  Sto nocnych zjaw. Duchy, demony i upiory w szt...
# 1450      53439                             Przygody Tomka Sawyera
# ...         ...                                                ...
# 5798      53870  Muzeum Fonografii w Niepołomicach – wystawa stała
# 5799      38200                                Projekt Kody Miasta
# 5800      53915                 Ostatnia Kolejka Czernichów Główny
# 5801      53870  Muzeum Fonografii w Niepołomicach – wystawa stała
# 5802      38200                                Projekt Kody Miasta
#
#       typ_wydarzenia_lista                          link_do_obrazka_lista  \
# 2951   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# 2041        Pokazy filmowe  http://media.krakow.travel/photos/69867/m.jpg
# 2694   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# 3497       Wystawy czasowe  http://media.krakow.travel/photos/73205/m.jpg
# 1450   Spektakle teatralne  http://media.krakow.travel/photos/69499/m.jpg
# ...                    ...                                            ...
# 5798  W gminach Metropolii  http://media.krakow.travel/photos/67020/m.jpg
# 5799     Akcje czytelnicze  http://media.krakow.travel/photos/47814/m.jpg
# 5800  W gminach Metropolii  http://media.krakow.travel/photos/66901/m.jpg
# 5801  W gminach Metropolii  http://media.krakow.travel/photos/67020/m.jpg
# 5802     Akcje czytelnicze  http://media.krakow.travel/photos/47814/m.jpg
#
#           sciezka_do_pobranego_obrazka  \
# 2951  obrazy_wydarzen_karnet/53439.jpg
# 2041  obrazy_wydarzen_karnet/56500.jpg
# 2694  obrazy_wydarzen_karnet/53439.jpg
# 3497  obrazy_wydarzen_karnet/59719.jpg
# 1450  obrazy_wydarzen_karnet/53439.jpg
# ...                                ...
# 5798  obrazy_wydarzen_karnet/53870.jpg
# 5799  obrazy_wydarzen_karnet/38200.jpg
# 5800  obrazy_wydarzen_karnet/53915.jpg
# 5801  obrazy_wydarzen_karnet/53870.jpg
# 5802  obrazy_wydarzen_karnet/38200.jpg
#
#                                            obiekty                ulice  \
# 2951  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# 2041                                    Kino Kijów  al. Krasińskiego 34
# 2694  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# 3497   Muzeum Sztuki i Techniki Japońskiej Manggha  ul. Konopnickiej 26
# 1450  Teatr Bagatela im. Tadeusza Boya-Żeleńskiego     ul. Karmelicka 6
# ...                                            ...                  ...
# 5798             Muzeum Fonografii w Niepołomicach        ul. Zamkowa 4
# 5799                                        Planty                  NaN
# 5800               Stacja Muzeum Czernichów Główny        ul. Wiślana 3
# 5801             Muzeum Fonografii w Niepołomicach        ul. Zamkowa 4
# 5802                                        Planty                  NaN
#
#            miasta data_rozpoczecia data_zakonczenia godzina_rozpoczecia  \
# 2951       Kraków       2025-06-01              NaT               11:00
# 2041       Kraków       2025-06-01              NaT               18:55
# 2694       Kraków       2025-06-01              NaT               11:00
# 3497       Kraków       2025-06-01       2025-08-31                 NaN
# 1450       Kraków       2025-06-01              NaT               11:00
# ...           ...              ...              ...                 ...
# 5798  Niepołomice              NaT              NaT                 NaN
# 5799       Kraków              NaT              NaT                 NaN
# 5800   Czernichów              NaT              NaT                 NaN
# 5801  Niepołomice              NaT              NaT                 NaN
# 5802       Kraków              NaT              NaT                 NaN
#
#              czy_stale               hashtagi  czy_na_zewnatrz
# 2951               NaN  #spektakle #teatralne                0
# 2041               NaN       #pokazy #filmowe                0
# 2694               NaN  #spektakle #teatralne                0
# 3497               NaN      #wystawy #czasowe                1
# 1450               NaN  #spektakle #teatralne                0
# ...                ...                    ...              ...
# 5798  Wydarzenie stałe  #WGminach #Metropolii                1
# 5799  Wydarzenie stałe    #akcje #czytelnicze                1
# 5800  Wydarzenie stałe  #WGminach #Metropolii                1
# 5801  Wydarzenie stałe  #WGminach #Metropolii                0
# 5802  Wydarzenie stałe    #akcje #czytelnicze                1
#
# [3132 rows x 14 columns]

# %%
df.dtypes
# Out:
# id_strony                                int64
# tytul                                   object
# typ_wydarzenia_lista                    object
# link_do_obrazka_lista                   object
# sciezka_do_pobranego_obrazka            object
# obiekty                                 object
# ulice                                   object
# miasta                                  object
# data_rozpoczecia                datetime64[ns]
# data_zakonczenia                datetime64[ns]
# godzina_rozpoczecia                     object
# czy_stale                               object
# hashtagi                                object
# czy_na_zewnatrz                          int32
# dtype: object

# %%
df.to_csv('wydarzenia_cleaned.csv', sep = ';')

# %%
df_krak = pd.read_csv('events_tiktak.csv', sep = ';')

# %%
df_krak
# Out:
#             tytul                            typ_wydarzenia  \
# 0    Wydarzenie 1  Wykłady, spacery i warsztaty artystyczne
# 1    Wydarzenie 2                             Wystawy stałe
# 2    Wydarzenie 3                       Festiwale teatralne
# 3    Wydarzenie 4                            Muzyka klubowa
# 4    Wydarzenie 5  Wykłady, spacery i warsztaty artystyczne
# 5    Wydarzenie 6                         Muzyka rozrywkowa
# 6    Wydarzenie 7                        Festiwale muzyczne
# 7    Wydarzenie 8                       Spektakle teatralne
# 8    Wydarzenie 9                          Muzyka klasyczna
# 9   Wydarzenie 10                         Muzyka rozrywkowa
# 10  Wydarzenie 11                         Targi i kiermasze
# 11  Wydarzenie 12                        Festiwale muzyczne
# 12  Wydarzenie 13                        Dziecięce różności
# 13  Wydarzenie 14                         Targi i kiermasze
# 14  Wydarzenie 15                            Pokazy filmowe
# 15  Wydarzenie 16          Widowiska plenerowe i happeningi
# 16  Wydarzenie 17                      Spacery i zwiedzanie
# 17  Wydarzenie 18                       Wydarzenia sportowe
# 18  Wydarzenie 19                         Akcje czytelnicze
# 19  Wydarzenie 20             Festiwale i przeglądy filmowe
# 20  Wydarzenie 21                                 Pozostałe
# 21  Wydarzenie 22                      Festiwale literackie
# 22  Wydarzenie 23                Inne wydarzenia literackie
# 23  Wydarzenie 24                       Festiwale teatralne
# 24  Wydarzenie 25                            Pokazy filmowe
# 25  Wydarzenie 26                             Inne koncerty
# 26  Wydarzenie 27                         Akcje czytelnicze
# 27  Wydarzenie 28                        Spektakle taneczne
# 28  Wydarzenie 29  Wykłady, spacery i warsztaty artystyczne
# 29  Wydarzenie 30                        Festiwale muzyczne
#
#                               obiekt                      ulice       miasto  \
# 0            Kopalnia Soli Wieliczka              Park Kingi 10    Wieliczka
# 1          Zamek Królewski na Wawelu                    Wawel 5       Kraków
# 2                       Rynek Główny               Rynek Główny       Kraków
# 3           Centrum Kultury i Sportu           ul. Bocheńska 26  Niepołomice
# 4          Zamek Królewski na Wawelu                    Wawel 5       Kraków
# 5         Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 6          Zamek Królewski na Wawelu                    Wawel 5       Kraków
# 7         Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 8                       Rynek Główny               Rynek Główny       Kraków
# 9                 Ogrody Doświadczeń              al. Pokoju 68       Kraków
# 10        Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 11  Muzeum Sztuki Współczesnej MOCAK                   Lipowa 4       Kraków
# 12                      Rynek Główny               Rynek Główny       Kraków
# 13        Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 14         Zamek Królewski na Wawelu                    Wawel 5       Kraków
# 15                      Rynek Główny               Rynek Główny       Kraków
# 16  Muzeum Sztuki Współczesnej MOCAK                   Lipowa 4       Kraków
# 17                      Rynek Główny               Rynek Główny       Kraków
# 18          Centrum Kultury i Sportu           ul. Bocheńska 26  Niepołomice
# 19        ICE Kraków Congress Centre  ul. Marii Konopnickiej 17       Kraków
# 20  Muzeum Sztuki Współczesnej MOCAK                   Lipowa 4       Kraków
# 21          Centrum Kultury i Sportu           ul. Bocheńska 26  Niepołomice
# 22         Zamek Królewski na Wawelu                    Wawel 5       Kraków
# 23                      Rynek Główny               Rynek Główny       Kraków
# 24        Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 25  Muzeum Sztuki Współczesnej MOCAK                   Lipowa 4       Kraków
# 26        Nowohuckie Centrum Kultury      al. Jana Pawła II 232       Kraków
# 27        ICE Kraków Congress Centre  ul. Marii Konopnickiej 17       Kraków
# 28           Kopalnia Soli Wieliczka              Park Kingi 10    Wieliczka
# 29                      Rynek Główny               Rynek Główny       Kraków
#
#               data_rozpoczecia            data_zakonczenia  \
# 0   2025-07-17 09:25:31.846627  2025-07-18 09:25:31.846627
# 1                          NaN                         NaN
# 2   2025-06-09 09:25:31.846655  2025-06-11 09:25:31.846655
# 3   2025-06-05 09:25:31.846665  2025-06-06 09:25:31.846665
# 4   2025-07-11 09:25:31.846685  2025-07-13 09:25:31.846685
# 5   2025-07-23 09:25:31.846694                         NaN
# 6   2025-07-06 09:25:31.846698  2025-07-06 09:25:31.846698
# 7   2025-06-09 09:25:31.846709  2025-06-11 09:25:31.846709
# 8   2025-06-25 09:25:31.846719                         NaN
# 9                          NaN                         NaN
# 10  2025-07-02 09:25:31.846734                         NaN
# 11  2025-06-02 09:25:31.846739  2025-06-02 09:25:31.846739
# 12  2025-06-24 09:25:31.846746  2025-06-26 09:25:31.846746
# 13  2025-06-23 09:25:31.846752  2025-06-25 09:25:31.846752
# 14                         NaN                         NaN
# 15  2025-06-20 09:25:31.846760                         NaN
# 16  2025-07-07 09:25:31.846765  2025-07-08 09:25:31.846765
# 17  2025-07-01 09:25:31.846772  2025-07-02 09:25:31.846772
# 18  2025-07-13 09:25:31.846777                         NaN
# 19                         NaN                         NaN
# 20  2025-07-10 09:25:31.846784  2025-07-11 09:25:31.846784
# 21  2025-07-04 09:25:31.846789  2025-07-05 09:25:31.846789
# 22                         NaN                         NaN
# 23  2025-06-16 09:25:31.846797                         NaN
# 24  2025-07-10 09:25:31.846802  2025-07-11 09:25:31.846802
# 25  2025-07-24 09:25:31.846809                         NaN
# 26  2025-06-23 09:25:31.846813  2025-06-24 09:25:31.846813
# 27                         NaN                         NaN
# 28  2025-07-07 09:25:31.846821  2025-07-09 09:25:31.846821
# 29  2025-06-04 09:25:31.846827                         NaN
#
#    godzina_rozpoczecia         czy_stale  czy_na_zewnatrz  \
# 0                  NaN               NaN                1
# 1                  NaN  Wydarzenie stałe                0
# 2                17:00               NaN                0
# 3                17:30               NaN                0
# 4                17:30               NaN                1
# 5                  NaN               NaN                0
# 6                14:00               NaN                0
# 7                19:00               NaN                0
# 8                11:30               NaN                1
# 9                  NaN  Wydarzenie stałe                0
# 10               12:00               NaN                0
# 11               17:00               NaN                1
# 12               11:30               NaN                0
# 13                 NaN               NaN                0
# 14                 NaN  Wydarzenie stałe                1
# 15               18:30               NaN                0
# 16               13:00               NaN                0
# 17                 NaN               NaN                0
# 18               17:00               NaN                1
# 19                 NaN  Wydarzenie stałe                1
# 20                 NaN               NaN                0
# 21               16:00               NaN                0
# 22                 NaN  Wydarzenie stałe                1
# 23               19:00               NaN                1
# 24               11:00               NaN                0
# 25               14:30               NaN                1
# 26                 NaN               NaN                1
# 27                 NaN  Wydarzenie stałe                1
# 28               19:00               NaN                1
# 29                 NaN               NaN                0
#
#                          sciezka_do_filmiku
# 0   filmiki\snaptik_7149243620598549765.mp4
# 1   filmiki\snaptik_7209665004247829765.mp4
# 2   filmiki\snaptik_7225907484010040602.mp4
# 3   filmiki\snaptik_7298831906970389792.mp4
# 4   filmiki\snaptik_7301022607674051872.mp4
# 5   filmiki\snaptik_7303850410421407009.mp4
# 6   filmiki\snaptik_7333556747816275232.mp4
# 7   filmiki\snaptik_7345843149518015777.mp4
# 8   filmiki\snaptik_7363729947195755808.mp4
# 9   filmiki\snaptik_7371878766118718753.mp4
# 10  filmiki\snaptik_7412386069150289185.mp4
# 11  filmiki\snaptik_7423729028638526742.mp4
# 12  filmiki\snaptik_7432805588272303382.mp4
# 13  filmiki\snaptik_7453921978995477782.mp4
# 14  filmiki\snaptik_7474408238453198102.mp4
# 15  filmiki\snaptik_7475369173263093014.mp4
# 16  filmiki\snaptik_7475407391719230742.mp4
# 17  filmiki\snaptik_7476014374163942678.mp4
# 18  filmiki\snaptik_7477972539462012182.mp4
# 19  filmiki\snaptik_7487884589415992578.mp4
# 20  filmiki\snaptik_7493208857683004694.mp4
# 21  filmiki\snaptik_7498423063495609622.mp4
# 22  filmiki\snaptik_7499575451203980566.mp4
# 23  filmiki\snaptik_7501723000648011030.mp4
# 24  filmiki\snaptik_7501725733480418582.mp4
# 25  filmiki\snaptik_7503988348650851606.mp4
# 26  filmiki\snaptik_7507660312049487126.mp4
# 27  filmiki\snaptik_7508066745903566102.mp4
# 28                                      NaN
# 29                                      NaN
